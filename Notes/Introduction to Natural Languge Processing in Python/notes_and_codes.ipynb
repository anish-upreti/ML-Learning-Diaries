# %% [markdown]
# Note: Most of the code snippets and notes are based on "Introduction to NLP in Python" course in DataCamp. Also some contents are AI generated.

# %% [markdown]
# Natural Language Processing (NLP) is a field at the intersection of computer science, artificial intelligence (AI), and linguistics. Its main goal is to enable machines to understand, interpret, and generate human (natural) language in a valuable and meaningful way.
#
# Here’s a detailed overview:
#
# ### 🔍 1. What is Natural Language Processing (NLP)?
#
# NLP enables computers to read, understand, and respond to human language — both spoken and written. It’s used in applications like:
#
# Chatbots
#
# Language translation (Google Translate)
#
# Sentiment analysis (e.g., for reviews or social media)
#
# Speech recognition (like Siri or Alexa)
#
# Text summarization
#
# Spam detection
#
# ### 🧠 2. Core Areas of NLP
#
# NLP consists of several subfields:
#
# ### a. Syntax – Structure of language
#
# Parsing: Analyzing grammatical structure of a sentence.
#
# Part-of-Speech Tagging: Identifying nouns, verbs, adjectives, etc.
#
# Sentence Segmentation: Dividing text into sentences.
#
# ### b. Semantics – Meaning of words and sentences
#
# Named Entity Recognition (NER): Identifying names of people, places, organizations, etc.
#
# Word Sense Disambiguation: Figuring out which meaning of a word is used in context.
#
# Semantic Role Labeling: Understanding the role of words in a sentence (subject, object, etc.).
#
# ### c. Pragmatics – Contextual understanding
#
# Discourse Analysis: Understanding how preceding sentences affect meaning.
#
# Coreference Resolution: Linking pronouns to the entities they refer to ("he", "she", "it").
#
# Intent Detection: Recognizing what the user wants (used in chatbots, voice assistants).
#
# ### 🛠️ 3. Key NLP Techniques
# ### a. Text Preprocessing
#
# Tokenization: Splitting text into words or sentences.
#
# Stop Word Removal: Removing common words (e.g., "is", "the").
#
# Stemming and Lemmatization: Reducing words to their base forms.
#
# Vectorization: Converting words into numbers (e.g., Bag-of-Words, TF-IDF).
#
# ### b. Machine Learning in NLP
#
# Supervised Learning: Used for classification tasks (e.g., spam detection).
#
# Unsupervised Learning: Topic modeling (e.g., LDA).
#
# Deep Learning: Neural networks (e.g., RNNs, LSTMs, Transformers).
#
# ### 🧪  NLP Applications
# | Application                     | Description                                   |
# | ------------------------------- | --------------------------------------------- |
# | **Machine Translation**         | Translating text from one language to another |
# | **Speech Recognition**          | Converting spoken language into text          |
# | **Text Summarization**          | Producing concise summaries of long texts     |
# | **Sentiment Analysis**          | Determining the emotional tone behind text    |
# | **Question Answering**          | Providing direct answers to user questions    |
# | **Chatbots/Virtual Assistants** | Engaging in conversation or completing tasks  |
#
#
#
# ### 📈 NLP Tools and Libraries
# | Library                          | Description                                                  |
# | -------------------------------- | ------------------------------------------------------------ |
# | **NLTK**                         | Natural Language Toolkit (good for learning and prototyping) |
# | **spaCy**                        | Industrial-strength NLP (fast and efficient)                 |
# | **Gensim**                       | Topic modeling and document similarity                       |
# | **Transformers by Hugging Face** | Pretrained transformer models                                |

# %% [markdown]
# # Part 1: Regular expressions and word tokenizations

# %% [markdown]
# Regular expressions are strings you can use that have a special syntax, which allows you to match patterns and find other strings. A pattern is a series of letters or symbols which can map to an actual text or words or punctuation. You can use regular expressions to do things like find links in a webpage, parse email addresses and remove unwanted strings or characters. Regular expressions are often referred to as regex and can be used easily with python via the `re` library.
#
# ### Common Regex patterns
# | **Pattern** | **Description**                              | **Example Match**                  |
# | ----------- | -------------------------------------------- | ---------------------------------- |
# | `.`         | Any character except newline                 | `a`, `1`, `!`                      |
# | `\d`        | Digit (0–9)                                  | `0`, `5`, `9`                      |
# | `\D`        | Non-digit character                          | `a`, `#`                           |
# | `\w`        | Word character (letters, digits, `_`)        | `a`, `Z`, `0`, `_`                 |
# | `\W`        | Non-word character                           | `!`, ` `, `%`                      |
# | `\s`        | Whitespace (space, tab, newline)             | ` `, `\t`, `\n`                    |
# | `\S`        | Non-whitespace character                     | `a`, `1`, `!`                      |
# | `^`         | Start of string/line                         | `^Hello` → matches "Hello..."      |
# | `$`         | End of string/line                           | `end$` → matches "...end"          |
# | `*`         | 0 or more repetitions                        | `a*` → `""`, `a`, `aaa`            |
# | `+`         | 1 or more repetitions                        | `a+` → `a`, `aa`, `aaa`            |
# | `?`         | 0 or 1 repetition (also used for non-greedy) | `a?` → `""`, `a`                   |
# | `{n}`       | Exactly n repetitions                        | `a{3}` → `aaa`                     |
# | `{n,}`      | n or more repetitions                        | `a{2,}` → `aa`, `aaa`, ...         |
# | `{n,m}`     | Between n and m repetitions                  | `a{2,4}` → `aa`, `aaa`, `aaaa`     |
# | `[...]`     | Any character inside brackets                | `[abc]` → `a`, `b`, `c`            |
# | `[^...]`    | Any character **not** inside brackets        | `[^abc]` → `d`, `x`                |
# | `( )`       | Grouping and capturing                       | `(abc)`                            |
# | `\b`        | Word boundary                                | `\bword\b` → matches "word" only   |
# | `\B`        | Non-word boundary                            | Matches "word" inside "password"   |
# | `\\`        | Escapes a special character                  | `\.` → literal dot `.`             |
#
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### What is tokenization?
# Tokenization is the process of transforming a string or document into smaller chunks, which we call tokens. This is usually one step in the process of preparing a text for natural language processing. There are many different theories and rules regarding tokenization, and you can create your own tokenization rules using regular expresssions, but normally tokenization will do things like break out words or sentences, often separate punctuation or you can even just tokenize parts of a string like separating all hashtags in a Tweet.
#
# One library that is commonly used for simple tokenization is nltk, the natural language toolkit library.
#
# ![image.png](attachment:image.png)
#
# ### Why tokenize?
# Why bother with tokenization? Because it can help us with some simple text processing tasks like mapping part of speech, matching common words and perhaps removing unwanted tokens like common words or repeated words.
#
# ![image-2.png](attachment:image-2.png)
#
# ### Using search and match
# When we use search and match with the same pattern and string with the pattern is at the beginning of the string, we see we find identical matches. That is the case with matching and searching abcde with the pattern abc. When we use search for a pattern that appears later in the string we get a result, but we don't get the same result using match. This is because match will try and match a string from the beginning until it cannot match any longer. Search will go through the ENTIRE string to look for match options. If you need to find a pattern that might not be at the beginning of the string, you should use search. If you want to be specific about the composition of the entire string, or at least the initial pattern, then you should use match.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
